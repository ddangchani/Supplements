# %% [markdown]
# # Matrix completion with Netflix rating data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
data = pd.read_csv('archive/Netflix_Dataset_Rating.csv')

# %%
ids = data.User_ID.unique()

import random
random.seed(42)

ids = random.sample(list(ids), 1000)
data = data[data.User_ID.isin(ids)]

# %%
# Data into a dataframe
df = pd.pivot(data=data, index='User_ID', columns='Movie_ID', values='Rating')

# %%
# count missing values
print(f'Number of missing values: {df.isnull().sum().sum()}')
print(f'Observing probability: {1- df.isnull().sum().sum() / (df.shape[0] * df.shape[1])}')
# Out:
# Number of missing values: 1228821
# Observing probability: 0.08976222222222219

# %%
# Inverse probability weighting
p = 0.1
r = 1

M_star = df.to_numpy()

# %%
P_M_star = df.fillna(0).values

# %%
M = (1 / p) * P_M_star

# %%
# rank r=5 SVD of M
U, Sigma, V_T = np.linalg.svd(M, full_matrices=False)

U = U[:, :r]
Sigma = Sigma[:r]
V = V_T.T
V = V[:, :r]

# %%
# Reconstruction
M = U @ np.diag(Sigma) @ V.T

# %%
df
# Out:
# Movie_ID  3     8     16    17    18    26    28    30    32    33    ...  \
# User_ID                                                               ...
# 9597       NaN   NaN   NaN   3.0   NaN   NaN   5.0   4.0   NaN   NaN  ...
# 11186      NaN   NaN   NaN   NaN   NaN   NaN   NaN   4.0   NaN   NaN  ...
# 11502      NaN   NaN   NaN   NaN   NaN   NaN   5.0   NaN   NaN   NaN  ...
# 13061      NaN   NaN   NaN   NaN   5.0   NaN   3.0   NaN   NaN   NaN  ...
# 19026      NaN   NaN   NaN   NaN   NaN   NaN   NaN   5.0   NaN   NaN  ...
# ...        ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 2638967    NaN   NaN   NaN   NaN   NaN   NaN   5.0   5.0   NaN   NaN  ...
# 2641316    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2642897    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2647351    NaN   NaN   NaN   NaN   NaN   NaN   NaN   3.0   NaN   5.0  ...
# 2648730    NaN   NaN   NaN   NaN   NaN   NaN   4.0   3.0   NaN   NaN  ...
#
# Movie_ID  4472  4474  4478  4479  4485  4488  4490  4492  4493  4496
# User_ID
# 9597       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 11186      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 11502      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 13061      NaN   NaN   NaN   NaN   NaN   4.0   NaN   NaN   NaN   NaN
# 19026      5.0   NaN   NaN   NaN   NaN   5.0   NaN   3.0   NaN   NaN
# ...        ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 2638967    2.0   NaN   NaN   NaN   NaN   4.0   NaN   NaN   NaN   NaN
# 2641316    NaN   NaN   NaN   4.0   NaN   4.0   NaN   NaN   NaN   NaN
# 2642897    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2647351    3.0   NaN   NaN   5.0   NaN   4.0   NaN   NaN   NaN   NaN
# 2648730    4.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1000 rows x 1350 columns]

# %%
# Prediction output

pd.DataFrame(M, index=df.index, columns=df.columns)
# Out:
# Movie_ID      3         8         16        17        18        26    \
# User_ID
# 9597      0.466357  2.480216  1.046366  1.367686  3.633661  1.137234
# 11186     0.447846  2.381770  1.004833  1.313398  3.489431  1.092094
# 11502     0.169256  0.900151  0.379760  0.496378  1.318774  0.412739
# 13061     0.261381  1.390098  0.586462  0.766553  2.036574  0.637391
# 19026     0.310651  1.652129  0.697009  0.911047  2.420465  0.757538
# ...            ...       ...       ...       ...       ...       ...
# 2638967   0.293964  1.563380  0.659567  0.862107  2.290443  0.716845
# 2641316   0.306514  1.630127  0.687726  0.898914  2.388231  0.747449
# 2642897   0.121453  0.645919  0.272503  0.356184  0.946308  0.296168
# 2647351   0.338667  1.801127  0.759869  0.993210  2.638756  0.825857
# 2648730   0.684918  3.642581  1.536751  2.008658  5.336593  1.670204
#
# Movie_ID       28         30        32        33    ...       4472      4474  \
# User_ID                                             ...
# 9597      12.532817  26.392558  0.866414  2.100113  ...  23.433076  1.571947
# 11186     12.035355  25.344964  0.832024  2.016754  ...  22.502952  1.509552
# 11502      4.548566   9.578716  0.314450  0.762199  ...   8.504624  0.570511
# 13061      7.024324  14.792354  0.485603  1.177060  ...  13.133640  0.881036
# 19026      8.348397  17.580689  0.577138  1.398934  ...  15.609310  1.047110
# ...             ...        ...       ...       ...  ...        ...       ...
# 2638967    7.899939  16.636291  0.546136  1.323786  ...  14.770810  0.990861
# 2641316    8.237218  17.346559  0.569452  1.380303  ...  15.401434  1.033165
# 2642897    3.263901   6.873371  0.225639  0.546929  ...   6.102638  0.409380
# 2647351    9.101302  19.166213  0.629188  1.525097  ...  17.017043  1.141544
# 2648730   18.406380  38.761553  1.272463  3.084341  ...  34.415094  2.308647
#
# Movie_ID      4478       4479      4485       4488      4490      4492  \
# User_ID
# 9597      1.025750   8.627691  1.660625  11.194300  2.357783  2.184228
# 11186     0.985035   8.285234  1.594710  10.749967  2.264196  2.097530
# 11502     0.372278   3.131269  0.602695   4.062775  0.855716  0.792727
# 13061     0.574907   4.835600  0.930738   6.274119  1.321477  1.224204
# 19026     0.683275   5.747103  1.106180   7.456780  1.570574  1.454965
# ...            ...        ...       ...        ...       ...       ...
# 2638967   0.646571   5.438380  1.046759   7.056217  1.486206  1.376807
# 2641316   0.674176   5.670566  1.091449   7.357475  1.549658  1.435588
# 2642897   0.267134   2.246895  0.432474   2.915313  0.614034  0.568835
# 2647351   0.744897   6.265408  1.205942   8.129274  1.712217  1.586181
# 2648730   1.506472  12.671098  2.438884  16.440560  3.462769  3.207877
#
# Movie_ID      4493      4496
# User_ID
# 9597      1.556859  2.654256
# 11186     1.495063  2.548902
# 11502     0.565035  0.963316
# 13061     0.872580  1.487643
# 19026     1.037059  1.768061
# ...            ...       ...
# 2638967   0.981351  1.673085
# 2641316   1.023248  1.744515
# 2642897   0.405450  0.691244
# 2647351   1.130587  1.927515
# 2648730   2.286488  3.898186
#
# [1000 rows x 1350 columns]

# %% [markdown]
# ### >> How to handle the overflow error ?
